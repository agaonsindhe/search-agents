# %% [markdown]
# # Artificial and Computational Intelligence Assignment 1

# %% [markdown]
# ## Problem solving by Uninformed & Informed Search

# %% [markdown]
# List only the BITS (Name) of active contributors in this assignment:
# 1. ___________________
# 2. __________________
# 3. ____________________
# 4. ___________________
# 5. ___________________

# %% [markdown]
# Things to follow
# 1.	Use appropriate data structures to represent the graph and the path using python libraries
# 2.	Provide proper documentation
# 3.	Find the path and print it

# %% [markdown]
# Coding begins here

# %% [markdown]
# ### 1.	Define the environment in the following block

# %% [markdown]
# List the PEAS decription of the problem here in this markdown block

# %% [markdown]
# Design the agent as PSA Agent(Problem Solving Agent)
# Clear Initial data structures to define the graph and variable declarations is expected
# IMPORTATANT: Write distinct code block as below

# %%
#Code Block : Set Initial State (Must handle dynamic inputs)
import math
from queue import PriorityQueue
def set_initial_state(start_city=None, destination_city=None):
    """
    Sets the initial state for the traveling problem with dynamic inputs.
    
    :param start_city: The starting city for the travel.
    :param destination_city: The destination city for the travel.
    :param kwargs: Additional parameters such as current location's latitude and longitude.
    :return: A dictionary representing the initial state of the problem.
    """
    initial_state = {
        'start_city': start_city,
        'destination_city': destination_city,
    }
    
    return initial_state

import random

# List of all cities in the graph
cities = ['Panaji', 'Raichur', 'Tirupathi', 'Chennai', 'Mangalore', 
          'Kozhikode', 'Bangalore', 'Bellari', 'Kurnool', 'Nellore']

# Distances between cities as provided in the graph
distances = {
    ('Panaji', 'Mangalore'): 365,
    ('Mangalore', 'Panaji'): 365,
    ('Panaji', 'Raichur'): 457,
    ('Raichur', 'Panaji'): 457,
    ('Raichur', 'Tirupathi'): 453,
    ('Tirupathi', 'Raichur'): 453,
    ('Raichur', 'Kurnool'): 100,
    ('Kurnool', 'Raichur'): 100,
    ('Mangalore', 'Kozhikode'): 233,
    ('Kozhikode', 'Mangalore'): 233,
    ('Mangalore', 'Bangalore'): 352,
    ('Bangalore', 'Mangalore'): 352,
    ('Kozhikode', 'Bangalore'): 356,
    ('Bangalore', 'Kozhikode'): 356,
    ('Bangalore', 'Chennai'): 346,
    ('Chennai', 'Bangalore'): 346,
    ('Bangalore', 'Bellari'): 153,
    ('Bellari', 'Bangalore'): 153,
    ('Bellari', 'Tirupathi'): 379,
    ('Tirupathi', 'Bellari'): 379,
    ('Tirupathi', 'Chennai'): 153,
    ('Chennai', 'Tirupathi'): 153,
    ('Kurnool', 'Nellore'): 325,
    ('Nellore', 'Kurnool'): 325,
    ('Nellore', 'Chennai'): 175,
    ('Chennai', 'Nellore'): 175
}

graph = {
    "Panaji": {"Mangalore": 365 , "Raichur": 457},
    "Mangalore": {"Panaji": 365, "Bangalore": 352, "Kozhikode": 233},
    "Bangalore": {"Mangalore": 352, "Kozhikode": 356, "Bellari": 153, "Chennai": 346},
    "Kozhikode": {"Mangalore": 233, "Bangalore": 356},
    "Tirupathi": {"Bellari": 379, "Raichur": 453, "Chennai": 153},
    "Nellore": {"Kurnool": 325, "Chennai": 175},
    "Chennai": {"Tirupathi": 153, "Nellore": 175,"Bangalore": 346},
    "Raichur": {"Panaji": 457,"Tirupathi": 453,"Kurnool": 100},
    "Bellari": {"Bangalore": 153,"Tirupathi": 379},
    "Kurnool": {"Nellore": 325,"Raichur": 100}
}

# Function to generate a random valid path between start and end cities
def generate_random_valid_path(start, end, cities):
    path = [start]
    while len(path) < len(cities):
        possible_moves = [city for city in cities if city not in path]
        next_city = random.choice(possible_moves)
        path.append(next_city)
    path.append(end)
    return path

def generate_valid_path(start_city, goal_city, map_connections):
    """
    Generate a valid path from start to city to goal city based on map connections.
    
    :param start_city: The starting city for the path.
    :param goal_city: The goal city for the path.
    :param map_connections: A dictionary or similar structure representing valid connections between cities.
    :return: A list representing a valid path.
    """
    path = [start_city]
    current_city = start_city
    while current_city != goal_city:
        # Get valid next steps from current city
        next_cities = [city for city in graph[current_city] if city not in path]
        if not next_cities:  # No valid next city, break to avoid infinite loop
            break
        next_city = random.choice(next_cities)
        path.append(next_city)
        current_city = next_city
    return path

# # Example usage:
# map_connections = {
#     'Panaji': ['Mangalore', 'Raichur'],
#     'Mangalore': ['Panaji', 'Kozhikode'],
#     # Add all connections as per the map provided
# }
# start_city, goal_city = 'Panaji', 'Chennai'
# initial_path = generate_valid_path(start_city, goal_city, map_connections)


# Function to create the initial state for ga: a population of paths
def set_initial_state_for_ga(start, end, cities, population_size):
    # Initialize the population with random paths
    population = []
    for _ in range(population_size):
        path = generate_valid_path(start, end, cities)
        population.append(path)
    return population

# Example usage:
population_size = 10  # This can be dynamically changed
initial_population = set_initial_state_for_ga('Panaji', 'Chennai', cities, population_size)

# This will print the initial population of paths
for path in initial_population:
    print(path)


# Example usage
# initial_state = set_initial_state(start_city='Panaji', destination_city='Chennai')
# print(initial_state)
# Out:
# ['Panaji', 'Mangalore', 'Kozhikode', 'Bangalore', 'Bellari', 'Tirupathi', 'Raichur', 'Kurnool', 'Nellore', 'Chennai']
# ['Panaji', 'Raichur', 'Kurnool', 'Nellore', 'Chennai']
# ['Panaji', 'Mangalore', 'Kozhikode', 'Bangalore', 'Chennai']
# ['Panaji', 'Mangalore', 'Kozhikode', 'Bangalore', 'Bellari', 'Tirupathi', 'Chennai']
# ['Panaji', 'Raichur', 'Kurnool', 'Nellore', 'Chennai']
# ['Panaji', 'Raichur', 'Kurnool', 'Nellore', 'Chennai']
# ['Panaji', 'Mangalore', 'Bangalore', 'Kozhikode']
# ['Panaji', 'Mangalore', 'Bangalore', 'Bellari', 'Tirupathi', 'Raichur', 'Kurnool', 'Nellore', 'Chennai']
# ['Panaji', 'Mangalore', 'Bangalore', 'Kozhikode']
# ['Panaji', 'Mangalore', 'Kozhikode', 'Bangalore', 'Chennai']

# %%
#Code Block : Set the matrix for transition & cost (as relevant for the given problem)

import math

cities_info = {
    "Panaji": (15.4909,73.8278),
    "Raichur": (16.2076,77.3463),
    "Mangalore": (12.9141,74.8560),
    "Bellari": (15.1394,76.9214),
    "Tirupathi": (13.6288, 79.4192),
    "Kurnool": (15.8281,78.0373),
    "Kozhikode": (11.2588,75.7804),
    "Bangalore": (12.9716,77.5946),
    "Nellore": (14.4426,79.9865),
    "Chennai":(13.0827,80.2707)
    # Add other cities here with their lat, long
}


def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # Convert decimal degrees to radians 
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    # Haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

def set_transition_and_cost_matrix(cities_info):
    """
    Initializes a matrix/dictionary representing the graph of cities with the cost of travel between them.
    
    :param cities_info: A dictionary with city names as keys and their lat, long as values.
    :return: A dictionary of dictionaries representing the distances between cities.
    """
    matrix = {}
    for city, (lat1, lon1) in cities_info.items():
        matrix[city] = {}
        for destination, (lat2, lon2) in cities_info.items():
            if city != destination: # Avoid distance to itself
                distance = haversine(lat1, lon1, lat2, lon2)
                matrix[city][destination] = distance
    return matrix

def get_heuristics(goal_city):
    heuristics = {}
    for k in cities_info.keys():
        distance = haversine(*cities_info[k],*cities_info[goal_city])
        heuristics[k]= distance
    return heuristics

transition_cost_matrix = set_transition_and_cost_matrix(cities_info)

import pandas as pd
# Convert to DataFrame for pretty printing
matrix_df = pd.DataFrame(transition_cost_matrix)

# Fill diagonal with 0s for clarity (no distance to itself)
for city in cities_info:
    if city in matrix_df.index:
        matrix_df.loc[city, city] = 0

matrix_df_reordered = matrix_df.reindex(index=cities_info, columns=cities_info)
        
matrix_df_reordered

# her = get_heuristics("Chennai")

# print(matrix_df_reordered," ",get_heuristics("Chennai"))

def calculate_total_distance(path, distances):
    """
    Calculate the total distance of the given path based on the road distances.
    
    :param path: A list of tuples representing the path (e.g., [('City1', 'City2'), ('City2', 'City3'), ...]).
    :param distances: A dictionary with city tuples as keys and distances as values.
    :return: The total distance of the path.
    """
    total_distance = 0
    for i in range(len(path) - 1):
        city_pair = (path[i], path[i+1])
        total_distance += distances.get(city_pair, 0)
    return total_distance

# def calculate_path_cost_debugged(path, distances):
#     total_cost = 0
#     for i in range(len(path) - 1):
#         segment = (path[i], path[i+1])
#         reverse_segment = (path[i+1], path[i])
        
#         if segment in distances:
#             total_cost += distances[segment]
#         elif reverse_segment in distances:
#             total_cost += distances[reverse_segment]
#         else:
#             # Debug print to identify missing segments
#             print(f"Warning: No distance found for segment {segment}. Check your distances dictionary.")
#             continue  # Continue accumulating cost for the rest of the path
        
#         # Debug print to show cost accumulation
#         print(f"Adding cost for {segment}: {distances.get(segment, distances.get(reverse_segment, 'N/A'))}, Total so far: {total_cost}")
    
#     return total_cost


def fitness_function(path, distances):
    total_distance = calculate_total_distance(path, distances)
    if total_distance <= 0:
        return 0  # Or a small epsilon value if you want to avoid zero fitness
    return 1 / total_distance

# %%
# Function to reconstruct the path from the start node to the goal node

def reconstruct_path(came_from, start, goal):
    """
    Reconstructs the path from start to goal using the came_from dictionary.

    :param came_from: A dictionary containing the parent of each node
    :param start: The starting city
    :param goal: The goal city
    :return: A list of cities representing the path from the start to the goal
    """
    current = goal
    path = [current]
    while current != start:
        current = came_from[current]
        path.append(current)
    path.reverse()  # reverse the path to get the correct order from start to goal
    return path

# Example usage:
came_from_example = {'Raichur': 'Panaji', 'Kurnool': 'Raichur', 'Chennai': 'Kurnool'}
start_city = 'Panaji'
goal_city = 'Chennai'
reconstructed_path = reconstruct_path(came_from_example, start_city, goal_city)

# Function to display the path beautifully
def display_path_beautifully(path):
    """
    Displays the path in a structured textual representation.

    :param path: A list of cities representing the path from the start to the goal
    """
    for i in range(len(path)):
        if i == len(path) - 1:  # if it's the last city, just print the city
            print(path[i])
        else:  # otherwise, print the city and an arrow
            print(f"{path[i]} -> ", end="")

            
def is_path_valid(path, map_connections):
    for i in range(len(path) - 1):
        if path[i+1] not in map_connections[path[i]]:
            return False
    return True

def repair_path(path, start_city, goal_city, map_connections):
    repaired_path = [start_city]
    for current_city in path:
        if repaired_path[-1] == goal_city:
            break
        next_cities = map_connections.get(repaired_path[-1], [])
        if current_city in next_cities:
            repaired_path.append(current_city)
        else:
            # Find a valid next city that is not already in the repaired_path
            # This is a simplistic approach; more sophisticated logic may be needed
            for possible_next in next_cities:
                if possible_next not in repaired_path:
                    repaired_path.append(possible_next)
                    break
    if repaired_path[-1] != goal_city:
        repaired_path.append(goal_city)  # Ensure the path ends at the goal city
    return repaired_path


# Display the path
# display_path_beautifully(reconstructed_path)

# %%
#Code Block : Write function to design the Transition Model/Successor function. Ideally this would be called while search algorithms are implemented

# State change function

def transition_model(current_city, graph):
    """
    Returns the successor states from the current city, along with the cost to reach each successor.

    :param current_city: The current city (state).
    :param graph: A dictionary representing the graph of cities, where keys are city names, and values are dictionaries
                  of neighboring cities and the distances to them.
    :return: A list of tuples, where each tuple contains a successor city and the cost to reach it.
    """
    successors = []
    if current_city in graph:
        for neighbor, cost in graph[current_city].items():
            successors.append((neighbor, cost))
    return successors

graph = {
    "Panaji": {"Mangalore": 365 , "Raichur": 457},
    "Mangalore": {"Panaji": 365, "Bangalore": 352, "Kozhikode": 233},
    "Bangalore": {"Mangalore": 352, "Kozhikode": 356, "Bellari": 153, "Chennai": 346},
    "Kozhikode": {"Mangalore": 233, "Bangalore": 356},
    "Tirupathi": {"Bellari": 379, "Raichur": 453, "Chennai": 153},
    "Nellore": {"Kurnool": 325, "Chennai": 175},
    "Chennai": {"Tirupathi": 153, "Nellore": 175,"Bangalore": 346},
    "Raichur": {"Panaji": 457,"Tirupathi": 453,"Kurnool": 100},
    "Bellari": {"Bangalore": 153,"Tirupathi": 379},
    "Kurnool": {"Nellore": 325,"Raichur": 100}
}

# Example usage
current_city = 'Panaji'
successors = transition_model(current_city, graph)
print(f"Successors from {current_city}: {successors}")

def selection(population, fitness_scores, selection_size):
    # Normalize fitness scores to use as probabilities for selection
    total_fitness = sum(fitness_scores)
    
    # Ensure total fitness is greater than zero and is finite
    if total_fitness <= 0 or not math.isfinite(total_fitness):
        raise ValueError("Invalid total fitness score: Must be greater than zero and finite.")
    
    selection_probabilities = [score / total_fitness for score in fitness_scores]
    
    # Select individuals based on their normalized fitness scores
    selected_indices = random.choices(
        range(len(population)), 
        weights=selection_probabilities, 
        k=selection_size
    )
    
    # Create a new list containing the selected individuals
    selected_population = [population[i] for i in selected_indices]
    return selected_population


# Example usage:
# Assuming `population` is your list of paths and `fitness_scores` is a list of their fitness scores
# selection_size = 5  # Number of individuals to select as parents
# parents = selection(population, fitness_scores, selection_size)


def transition_model_for_ga(population, fitness_scores, crossover_rate, mutation_rate, distances, cities):
    """
    Creates the next generation using selection, crossover, and mutation.
    
    :param population: The current generation of paths.
    :param fitness_scores: The fitness scores for each path in the population.
    :param crossover_rate: The probability that crossover will occur.
    :param mutation_rate: The probability that mutation will occur.
    :param distances: The dictionary with distances between cities.
    :param cities: The list of all cities.
    :return: The next generation of paths.
    """
    # Selection
    selected_parents = selection(population, fitness_scores, len(population))
    
    # Crossover
    offspring = []
    for _ in range(0, len(selected_parents), 2):
        if random.random() < crossover_rate:
            parent1, parent2 = selected_parents[_], selected_parents[_+1]
            child1, child2 = crossover(parent1, parent2, cities)
            offspring.extend([child1, child2])
        else:
            offspring.extend([selected_parents[_], selected_parents[_+1]])
    
    # Mutation
    for individual in offspring:
        if random.random() < mutation_rate:
            mutate(individual, cities)
    
    # Evaluation
    new_fitness_scores = [fitness_function(path, distances) for path in offspring]
    
    # Replacement (this can be different depending on the replacement strategy)
    # For simplicity, we replace the old population with the new offspring
    new_population = offspring
    
    return new_population, new_fitness_scores

def crossover(parent1, parent2, cities):
    # Ensure paths are long enough for crossover
    min_length = min(len(parent1), len(parent2))
    if min_length <= 3:
        # If paths are too short, return them as is or handle differently
        return parent1, parent2

    # Proceed with crossover
    crossover_point = random.randint(1, min_length - 2)
    offspring1 = parent1[:crossover_point] + parent2[crossover_point:]
    offspring2 = parent2[:crossover_point] + parent1[crossover_point:]

    # Ensure the offspring are valid paths
    offspring1 = [city for city in cities if city in offspring1]
    offspring2 = [city for city in cities if city in offspring2]

    return offspring1, offspring2



def mutate(path, mutation_rate):
    """
    Mutate a path by swapping two cities with a given probability.
    
    :param path: The path to mutate.
    :param mutation_rate: The probability of mutating a given gene.
    :return: The mutated path.
    """
    mutated_path = path.copy()
    for i in range(len(mutated_path)):
        if random.random() < mutation_rate:
            swap_index = random.randint(0, len(mutated_path) - 1)
            # Swap the cities at i and swap_index
            mutated_path[i], mutated_path[swap_index] = mutated_path[swap_index], mutated_path[i]
    return mutated_path
# Out:
# Successors from Panaji: [('Mangalore', 365), ('Raichur', 457)]

# %%
#Code block : Write fucntion to handle goal test (Must handle dynamic inputs). Ideally this would be called while search algorithms are implemented

#goaltest

# Goal Test Function
def is_goal_reached(current_city, goal):
    """
    Test if the current city is the goal.

    :param current_city: The current city
    :param goal: The goal city
    :return: True if the current city is the goal, False otherwise
    """
    return current_city == goal

def is_goal_reached_for_ga(path, goal_city):
    """
    Check if the goal city has been reached in the given path.
    
    :param path: A list representing the path taken, with each element being a city name.
    :param goal_city: The goal city name as a string.
    :return: True if the goal city is the last city in the path, False otherwise.
    """
    # Check if the last city in the path is the goal city
    return path[-1] == goal_city

# Example usage
# goal_city = 'Chennai'
# path = ['Panaji', 'Raichur', 'Tirupathi', 'Chennai']  # Example path
# goal_reached = is_goal_reached(path, goal_city)
# print(f"Goal Reached: {goal_reached}")

# %% [markdown]
# ### 2.	Definition of Algorithm 1 (Greedy BFS)

# %%
#Code Block : Function for algorithm 1 implementation


import heapq

# Modify the Greedy Best First Search Algorithm to include total cost
def greedy_best_first_search(graph, start, goal, heuristics):
    """
    Greedy Best First Search Algorithm implementation that also calculates total cost.

    :param graph: The graph as a dictionary of cities and their connected cities with distances
    :param start: The starting city
    :param goal: The goal city
    :param heuristics: A dictionary of heuristic values for each city
    :return: A tuple containing the path from start to goal as determined by GBFS and the total cost
    """
    # Priority queue for the frontier cities, ordered by heuristic value
    frontier = []
    heapq.heappush(frontier, (heuristics[start], 0, start))  # includes current cost as 0

    # Dictionary to keep track of the path that led to each city
    came_from = {start: None}

    # Dictionary to keep track of the cost to reach each city
    cost_so_far = {start: 0}

    # The set of explored cities to avoid revisiting them
    explored = set()

    # GBFS loop
    while frontier:
        # Choose the city with the lowest heuristic value
        _, current_cost, current_city = heapq.heappop(frontier)

         # Call the goal test function
        if is_goal_reached(current_city, goal):
            return reconstruct_path(came_from, start, goal), current_cost

        # Mark the city as explored
        explored.add(current_city)
        
        successors = transition_model(current_city, graph)
        print(f"Successors from {current_city}: {successors}")
        
        # Add neighboring cities to the frontier if they haven't been explored or
        # if a cheaper path to them has been found
        # Use the transition_model function to get successors and their costs
        for neighbor, distance in transition_model(current_city, graph):
            new_cost = current_cost + distance
            if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                cost_so_far[neighbor] = new_cost
                heapq.heappush(frontier, (heuristics[neighbor], new_cost, neighbor))
                came_from[neighbor] = current_city

    # If the goal was never reached, return None
    return None, None

# %% [markdown]
# ### 3.	Definition of Algorithm 2 (Genetic)

# %%
#Code Block : Function for algorithm 2 implementation

#genetic

import random

# Assuming all necessary functions like fitness_function, selection, crossover, mutate, and is_goal_reached are defined

def genetic_algorithm(cities, distances, population_size, generations, crossover_rate, mutation_rate, goal_city):
    """
    Implements a Genetic Algorithm to find the most optimal path to the goal city.
    
    :param cities: List of all cities in the problem.
    :param distances: Dictionary with distances between each pair of cities.
    :param population_size: Number of paths in each generation.
    :param generations: Maximum number of generations to evolve.
    :param crossover_rate: Probability of applying crossover.
    :param mutation_rate: Probability of applying mutation.
    :param goal_city: The destination city for the pathfinding problem.
    :return: The most optimal path found and its distance.
    """
    # Initialize the population randomly
    # population = [generate_random_valid_path(cities[0], goal_city, cities) for _ in range(population_size)]
    population = set_initial_state_for_ga(start_city, goal_city, cities, population_size)
    best_path = None
    best_fitness = 0
    
    for generation in range(generations):
        # Evaluate the fitness of each individual in the population
        fitness_scores = [fitness_function(path, distances) for path in population]
        
        # Check for the goal
        for i, path in enumerate(population):
            if is_goal_reached(path, goal_city) and fitness_scores[i] > best_fitness:
                best_path = path
                best_fitness = fitness_scores[i]
        
        # Selection
        parents = selection(population, fitness_scores, len(population) // 2)
        
        # Crossover and Mutation
        offspring = []
        for _ in range(0, len(parents), 2):
            if random.random() < crossover_rate:
                child1, child2 = crossover(parents[_], parents[_+1], cities)
                offspring.append(mutate(child1, mutation_rate))
                offspring.append(mutate(child2, mutation_rate))
            else:
                offspring.append(mutate(parents[_], mutation_rate))
                offspring.append(mutate(parents[_+1], mutation_rate))
        
        # Creating the new generation
        population = parents + offspring[:len(population) - len(parents)]
        
        print(f"Generation {generation + 1}: Best Path Distance = {1 / best_fitness if best_fitness else 'Not found'}")
    
    return best_path, 1 / best_fitness if best_fitness else None


import random

def genetic_algorithm_with_elitism(cities, distances, population_size, generations, crossover_rate, mutation_rate, goal_city, number_of_elites=1):
    """
    Implements a Genetic Algorithm with elitism to find the most optimal path to the goal city.
    
    :param cities: List of all cities in the problem.
    :param distances: Dictionary with distances between each pair of cities.
    :param population_size: Number of paths in each generation.
    :param generations: Maximum number of generations to evolve.
    :param crossover_rate: Probability of applying crossover.
    :param mutation_rate: Probability of applying mutation.
    :param goal_city: The destination city for the pathfinding problem.
    :param number_of_elites: The number of top individuals to carry over directly to the next generation.
    :return: The most optimal path found and its distance.
    """
    # Initialize the population
    population = set_initial_state_for_ga(cities[0], goal_city, cities, population_size)
    best_path = None
    best_fitness = 0
    
    for generation in range(generations):
        # Evaluate the fitness of each individual in the population
        fitness_scores = [fitness_function(path, distances) for path in population]
        
        # Preserve the top individuals as elites
        elites_indices = sorted(range(len(fitness_scores)), key=lambda i: fitness_scores[i], reverse=True)[:number_of_elites]
        elites = [population[i] for i in elites_indices]
        
        # Selection (excluding elites if they are not to be mutated)
        parents = selection(population, fitness_scores, len(population) // 2)
        
        # Adjusting the parent list to ensure an even number for crossover
        if len(parents) % 2 != 0:
            # Remove the last parent if the count is odd
            # You might choose a different strategy based on your specific requirements
            parents.pop()
        
        # Crossover and Mutation
        offspring = []
# Example of applying the check and repair in the main GA loop
        for _ in range(0, len(parents), 2):
            if random.random() < crossover_rate:
                child1, child2 = crossover(parents[_], parents[_+1], cities)
            else:
                child1, child2 = parents[_], parents[_+1]

            child1 = mutate(child1, mutation_rate)
            child2 = mutate(child2, mutation_rate)

            if not is_path_valid(child1, graph):
                child1 = repair_path(child1, start_city, goal_city, graph)
            if not is_path_valid(child2, graph):
                child2 = repair_path(child2, start_city, goal_city, graph)

            offspring.extend([child1, child2])
        
        # Combine elites with offspring to form the new generation
        new_population = elites + offspring[:population_size - len(elites)]
        population = new_population
        
        # Update best path if a new best is found
        for elite in elites:
            elite_fitness = fitness_function(elite, distances)
            if elite_fitness > best_fitness:
                best_path = elite
                best_fitness = elite_fitness
        
        print(f"Generation {generation + 1}: Best Path Distance = {1 / best_fitness if best_fitness else 'Not found'}")
    
    return best_path, 1 / best_fitness if best_fitness else None


# # Parameters (example values, adjust as needed)
# population_size = 100
# generations = 50
# crossover_rate = 0.7
# mutation_rate = 0.1
# goal_city = 'Chennai'

# # List of cities and distances would be defined as per the earlier setup
# # Assuming 'cities' and 'distances' are already defined

# # Running the GA
# best_path, best_distance = genetic_algorithm(cities, distances, population_size, generations, crossover_rate, mutation_rate, goal_city)
# print(f"Best Path: {best_path}\nBest Distance: {best_distance}")

# %% [markdown]
# ### DYNAMIC INPUT

# %% [markdown]
# IMPORTANT : Dynamic Input must be got in this section. Display the possible states to choose from:
# This is applicable for all the relevent problems as mentioned in the question.

# %%
#Code Block : Function & call to get inputs (start/end state)

def get_start_end_states(cities):
    """
    Prompt the user to select the start and end states for the journey by number instead of typing names.

    :param cities: A list of available cities.
    :return: A tuple containing the start and end states.
    """
    # Display cities with numbers
    for i, city in enumerate(cities, 1):
        print(f"{i}. {city}")

    while True:
        try:
            start_index = int(input("Select the number for the start city: ")) - 1
            if start_index not in range(len(cities)):
                print("Invalid selection. Please select a number from the list.")
                continue

            end_index = int(input("Select the number for the destination city: ")) - 1
            if end_index not in range(len(cities)):
                print("Invalid selection. Please select a number from the list.")
                continue

            if start_index == end_index:
                print("Start and destination cities cannot be the same. Please select different cities.")
                continue

            start = cities[start_index]
            end = cities[end_index]

            return start, end
        except ValueError:
            print("Invalid input. Please enter a number.")

# Assuming a list of cities based on the given problem
cities_list = ["Panaji", "Raichur", "Mangalore", "Bellari", "Tirupathi", "Kurnool", "Kozhikode", "Bangalore", "Nellore", "Chennai"]

# # Call the function to get start and end states
# start_city, end_city = get_start_end_states(cities_list)
# print(f"Starting from: {start_city}, Destination: {end_city}")

# %% [markdown]
# ### 4.	Calling the search algorithms
# (For bidirectional search in below sections first part can be used as per Hint provided. Under second section other combinations as per Hint or your choice of 2 algorithms can be called .As an analyst suggest suitable approximation in the comparitive analysis section)

# %%
#Invoke algorithm 1 (Should Print the solution, path, cost etc., (As mentioned in the problem))

# Call the function to get start and end states
start_city, end_city = get_start_end_states(cities_list)


# Prepare initial state
initial_state = set_initial_state(start_city, end_city)

# Implement GBFS with cost
path_gbfs, total_cost_gbfs = greedy_best_first_search(graph, start_city, end_city, get_heuristics("Chennai"))

# Display the path and total cost if a path was found
if path_gbfs:
    display_path_beautifully(path_gbfs)
    print(f"Total cost: {total_cost_gbfs} km")
else:
    print("No path found from Panaji to Chennai using GBFS.")
# Out:
# 1. Panaji
# 2. Raichur
# 3. Mangalore
# 4. Bellari
# 5. Tirupathi
# 6. Kurnool
# 7. Kozhikode
# 8. Bangalore
# 9. Nellore
# 10. Chennai
# Select the number for the start city:  1
# Select the number for the destination city:  10
# Successors from Panaji: [('Mangalore', 365), ('Raichur', 457)]
# Successors from Raichur: [('Panaji', 457), ('Tirupathi', 453), ('Kurnool', 100)]
# Successors from Tirupathi: [('Bellari', 379), ('Raichur', 453), ('Chennai', 153)]
# Panaji -> Raichur -> Tirupathi -> Chennai
# Total cost: 1063 km

# %%
#Invoke algorithm 2 (Should Print the solution, path, cost etc., (As mentioned in the problem))

#genetic returning tuple for outputs

# Assuming cities, distances, and all necessary functions are already defined

# Get start and end cities for the algorithm
start_city, goal_city = get_start_end_states(cities_list)

population_size = 200

initial_population = set_initial_state_for_ga(start_city, goal_city, cities, population_size)
initial_population
# Define Genetic Algorithm parameters

generations = 100
crossover_rate = 0.8
mutation_rate = 0.2

# Invoke the Genetic Algorithm
best_path, best_distance = genetic_algorithm_with_elitism(
    cities, distances, population_size, generations, crossover_rate, mutation_rate, goal_city
)

# Print the solution
if best_path and best_distance:
    print(f"Solution Found:\nPath: {' -> '.join(best_path)}\nCost (Total Distance): {best_distance} km")
else:
    print("No solution found within the given constraints.")
# Out:
# 1. Panaji
# 2. Raichur
# 3. Mangalore
# 4. Bellari
# 5. Tirupathi
# 6. Kurnool
# 7. Kozhikode
# 8. Bangalore
# 9. Nellore
# 10. Chennai
# Select the number for the start city:  1
# Select the number for the destination city:  10
# Generation 1: Best Path Distance = 1057.0
# Generation 2: Best Path Distance = 954.0
# Generation 3: Best Path Distance = 954.0
# Generation 4: Best Path Distance = 954.0
# Generation 5: Best Path Distance = 954.0
# Generation 6: Best Path Distance = 954.0
# Generation 7: Best Path Distance = 954.0
# Generation 8: Best Path Distance = 954.0
# Generation 9: Best Path Distance = 954.0
# Generation 10: Best Path Distance = 954.0
# Generation 11: Best Path Distance = 954.0
# Generation 12: Best Path Distance = 954.0
# Generation 13: Best Path Distance = 954.0
# Generation 14: Best Path Distance = 954.0
# Generation 15: Best Path Distance = 954.0
# Generation 16: Best Path Distance = 954.0
# Generation 17: Best Path Distance = 954.0
# Generation 18: Best Path Distance = 954.0
# Generation 19: Best Path Distance = 954.0
# Generation 20: Best Path Distance = 954.0
# Generation 21: Best Path Distance = 954.0
# Generation 22: Best Path Distance = 954.0
# Generation 23: Best Path Distance = 954.0
# Generation 24: Best Path Distance = 954.0
# Generation 25: Best Path Distance = 954.0
# Generation 26: Best Path Distance = 954.0
# Generation 27: Best Path Distance = 954.0
# Generation 28: Best Path Distance = 954.0
# Generation 29: Best Path Distance = 954.0
# Generation 30: Best Path Distance = 954.0
# Generation 31: Best Path Distance = 954.0
# Generation 32: Best Path Distance = 954.0
# Generation 33: Best Path Distance = 954.0
# Generation 34: Best Path Distance = 954.0
# Generation 35: Best Path Distance = 954.0
# Generation 36: Best Path Distance = 954.0
# Generation 37: Best Path Distance = 954.0
# Generation 38: Best Path Distance = 954.0
# Generation 39: Best Path Distance = 954.0
# Generation 40: Best Path Distance = 954.0
# Generation 41: Best Path Distance = 954.0
# Generation 42: Best Path Distance = 954.0
# Generation 43: Best Path Distance = 954.0
# Generation 44: Best Path Distance = 954.0
# Generation 45: Best Path Distance = 954.0
# Generation 46: Best Path Distance = 954.0
# Generation 47: Best Path Distance = 954.0
# Generation 48: Best Path Distance = 954.0
# Generation 49: Best Path Distance = 954.0
# Generation 50: Best Path Distance = 954.0
# Generation 51: Best Path Distance = 954.0
# Generation 52: Best Path Distance = 954.0
# Generation 53: Best Path Distance = 954.0
# Generation 54: Best Path Distance = 954.0
# Generation 55: Best Path Distance = 954.0
# Generation 56: Best Path Distance = 954.0
# Generation 57: Best Path Distance = 954.0
# Generation 58: Best Path Distance = 954.0
# Generation 59: Best Path Distance = 954.0
# Generation 60: Best Path Distance = 954.0
# Generation 61: Best Path Distance = 954.0
# Generation 62: Best Path Distance = 954.0
# Generation 63: Best Path Distance = 954.0
# Generation 64: Best Path Distance = 954.0
# Generation 65: Best Path Distance = 954.0
# Generation 66: Best Path Distance = 954.0
# Generation 67: Best Path Distance = 954.0
# Generation 68: Best Path Distance = 954.0
# Generation 69: Best Path Distance = 954.0
# Generation 70: Best Path Distance = 954.0
# Generation 71: Best Path Distance = 954.0
# Generation 72: Best Path Distance = 954.0
# Generation 73: Best Path Distance = 954.0
# Generation 74: Best Path Distance = 954.0
# Generation 75: Best Path Distance = 954.0
# Generation 76: Best Path Distance = 954.0
# Generation 77: Best Path Distance = 954.0
# Generation 78: Best Path Distance = 954.0
# Generation 79: Best Path Distance = 954.0
# Generation 80: Best Path Distance = 954.0
# Generation 81: Best Path Distance = 954.0
# Generation 82: Best Path Distance = 954.0
# Generation 83: Best Path Distance = 954.0
# Generation 84: Best Path Distance = 954.0
# Generation 85: Best Path Distance = 954.0
# Generation 86: Best Path Distance = 954.0
# Generation 87: Best Path Distance = 954.0
# Generation 88: Best Path Distance = 954.0
# Generation 89: Best Path Distance = 954.0
# Generation 90: Best Path Distance = 954.0
# Generation 91: Best Path Distance = 954.0
# Generation 92: Best Path Distance = 954.0
# Generation 93: Best Path Distance = 954.0
# Generation 94: Best Path Distance = 954.0
# Generation 95: Best Path Distance = 954.0
# Generation 96: Best Path Distance = 954.0
# Generation 97: Best Path Distance = 954.0
# Generation 98: Best Path Distance = 954.0
# Generation 99: Best Path Distance = 954.0
# Generation 100: Best Path Distance = 954.0
# Solution Found:
# Path: Panaji -> Mangalore -> Kozhikode -> Bangalore
# Cost (Total Distance): 954.0 km

# %% [markdown]
# ### 5.	Comparitive Analysis

# %%
#Code Block : Print the Time & Space complexity of algorithm 1

# time & space of gbfs

# %%
#Code Block : Print the Time & Space complexity of algorithm 2

# %% [markdown]
# ### 6.	Provide your comparitive analysis or findings in no more than 3 lines in below section

# %% [markdown]
# Comparison : _______________________________________________
#
# ________________________________________________________
#
# _________________________________________________________
